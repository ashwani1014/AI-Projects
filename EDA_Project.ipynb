# %% [markdown]
# # Ames Housing — Exploratory Data Analysis
#
# ## Objective
# Analyze the Ames Housing dataset to understand the factors
# that influence house sale prices.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # **Pandas Library Operations**

# %%
df = pd.read_csv("Ames_Housing_EDA.csv")
df.head(2)
df.shape
# Out:
# (1005, 15)

# %%
df.head()
# Out:
#    OverallQual  GrLivArea  YearBuilt  TotalBsmtSF  FullBath  BedroomAbvGr  \
# 0            9     1654.0       1971       1592.0         1             4
# 1            6     2344.0       1948        716.0         1             2
# 2            7     1928.0       1978       1138.0         1             1
# 3            9     1240.0       1916       1308.0         1             2
# 4            5     1096.0       1959       1337.0         2             1
#
#    GarageCars  GarageArea  LotArea Neighborhood HouseStyle Exterior  \
# 0           2       585.0  12630.0      NridgHt     2Story  Plywood
# 1           1       515.0  13025.0      Gilbert     1Story  MetalSd
# 2           1       983.0   5569.0      Crawfor     1Story  MetalSd
# 3           3       644.0   9205.0      Edwards     SFoyer  Plywood
# 4           2       600.0   7750.0      Gilbert       SLvl  BrkFace
#
#   GarageType SaleCondition  SalePrice
# 0    CarPort        Normal     514675
# ...

# %%
df.columns
# Out:
# Index(['OverallQual', 'GrLivArea', 'YearBuilt', 'TotalBsmtSF', 'FullBath',
#        'BedroomAbvGr', 'GarageCars', 'GarageArea', 'LotArea', 'Neighborhood',
#        'HouseStyle', 'Exterior', 'GarageType', 'SaleCondition', 'Sale_Price'],
#       dtype='object')

# %%
df.describe()
# Out:
#        OverallQual    GrLivArea    YearBuilt  TotalBsmtSF     FullBath  \
# count  1005.000000  1005.000000  1005.000000   990.000000  1005.000000
# mean      6.499502  1522.857711  1959.315423  1033.228283     2.023881
# std       2.305210   462.339261    35.547048   411.671704     0.816554
# min       3.000000   500.000000  1900.000000     0.000000     1.000000
# 25%       5.000000  1218.000000  1927.000000   762.750000     1.000000
# 50%       6.000000  1516.000000  1958.000000  1048.000000     2.000000
# 75%       9.000000  1809.000000  1990.000000  1297.000000     3.000000
# max      10.000000  5200.000000  2020.000000  2304.000000     3.000000
#
#        BedroomAbvGr   GarageCars   GarageArea       LotArea     SalePrice
# count   1005.000000  1005.000000   990.000000    990.000000  1.005000e+03
# mean       2.942289     1.494527   459.716162  10066.544444  3.514078e+05
# std        1.422868     1.119022   176.237939   5266.207119  8.330369e+04
# ...

# %%
df[df['YearBuilt']>2006]
# Out:
#      OverallQual  GrLivArea  YearBuilt  TotalBsmtSF  FullBath  BedroomAbvGr  \
# 18            10     1297.0       2020        330.0         2             5
# 22             4     1554.0       2008       1532.0         3             1
# 34             8     2427.0       2009         19.0         3             4
# 41             9     1809.0       2014        866.0         1             2
# 49             8     1533.0       2017        138.0         2             5
# ..           ...        ...        ...          ...       ...           ...
# 947           10     2171.0       2012        262.0         3             1
# 953            6     1577.0       2008        692.0         1             2
# 962            8      885.0       2012       1080.0         3             1
# 971            9     1676.0       2016        954.0         2             2
# 996            3     2471.0       2009        714.0         2             4
#
# ...

# %%
df['BedroomAbvGr']
# Out:
# 0       4
# 1       2
# 2       1
# 3       2
# 4       1
#        ..
# 1000    1
# 1001    2
# 1002    5
# 1003    1
# 1004    1
# Name: BedroomAbvGr, Length: 1005, dtype: int64

# %%
df.loc[0]
# Out:
# OverallQual            9
# GrLivArea         1654.0
# YearBuilt           1971
# TotalBsmtSF       1592.0
# FullBath               1
# BedroomAbvGr           4
# GarageCars             2
# GarageArea         585.0
# LotArea          12630.0
# Neighborhood     NridgHt
# HouseStyle        2Story
# Exterior         Plywood
# GarageType       CarPort
# SaleCondition     Normal
# SalePrice         514675
# Name: 0, dtype: object

# %%
df[
    (df["SalePrice"] > 300000) &
    (df["OverallQual"] >= 8)
]
# Out:
#       OverallQual  GrLivArea  YearBuilt  TotalBsmtSF  FullBath  BedroomAbvGr  \
# 0               9     1654.0       1971       1592.0         1             4
# 3               9     1240.0       1916       1308.0         1             2
# 5              10     5200.0       1986        534.0         3             2
# 8               9     2031.0       1982       1324.0         2             2
# 11              9     2109.0       1943        518.0         2             5
# ...           ...        ...        ...          ...       ...           ...
# 984            10     1422.0       1916       1070.0         2             5
# 989            10     1406.0       1938        843.0         1             2
# 998            10     1834.0       1910       1370.0         3             2
# 1001            8     1020.0       1942        789.0         2             2
# 1004            9     2233.0       1995       1598.0         1             1
#
# ...

# %%
df[(df['GarageCars']>2)&(df['LotArea']>2000)
   ]
# Out:
#       OverallQual  GrLivArea  YearBuilt  TotalBsmtSF  FullBath  BedroomAbvGr  \
# 3               9     1240.0       1916       1308.0         1             2
# 6               7      906.0       1987       1421.0         1             1
# 7               7     2324.0       1944        608.0         1             1
# 9               4     1289.0       1968       1214.0         2             2
# 15              7     1230.0       1907        673.0         3             1
# ...           ...        ...        ...          ...       ...           ...
# 981            10     1080.0       1936        798.0         2             5
# 984            10     1422.0       1916       1070.0         2             5
# 985             4     2270.0       1987        584.0         1             2
# 987             6      774.0       1950        859.0         2             5
# 1001            8     1020.0       1942        789.0         2             2
#
# ...

# %%
df.sort_values("SalePrice")
# Out:
#      OverallQual  GrLivArea  YearBuilt  TotalBsmtSF  FullBath  BedroomAbvGr  \
# 158            3      500.0       1949        951.0         3             1
# 711            4      601.0       1947        640.0         2             4
# 139            3      688.0       1922        533.0         3             3
# 192            3      835.0       1904        837.0         2             3
# 550            3     1040.0       1913       1106.0         2             2
# ..           ...        ...        ...          ...       ...           ...
# 642           10     1776.0       2016       1422.0         3             3
# 433           10     1979.0       1967       1216.0         1             1
# 829           10     2061.0       1951       1516.0         3             1
# 555           10     1893.0       1927        893.0         1             1
# 25             8      994.0       1998       1365.0         2             2
#
# ...

# %%
df.sort_values("SalePrice", ascending=False)
# Out:
#      OverallQual  GrLivArea  YearBuilt  TotalBsmtSF  FullBath  BedroomAbvGr  \
# 25             8      994.0       1998       1365.0         2             2
# 555           10     1893.0       1927        893.0         1             1
# 829           10     2061.0       1951       1516.0         3             1
# 433           10     1979.0       1967       1216.0         1             1
# 642           10     1776.0       2016       1422.0         3             3
# ..           ...        ...        ...          ...       ...           ...
# 550            3     1040.0       1913       1106.0         2             2
# 192            3      835.0       1904        837.0         2             3
# 139            3      688.0       1922        533.0         3             3
# 711            4      601.0       1947        640.0         2             4
# 158            3      500.0       1949        951.0         3             1
#
# ...

# %%
df.isnull()
# Out:
#       OverallQual  GrLivArea  YearBuilt  TotalBsmtSF  FullBath  BedroomAbvGr  \
# 0           False      False      False        False     False         False
# 1           False      False      False        False     False         False
# 2           False      False      False        False     False         False
# 3           False      False      False        False     False         False
# 4           False      False      False        False     False         False
# ...           ...        ...        ...          ...       ...           ...
# 1000        False      False      False        False     False         False
# 1001        False      False      False        False     False         False
# 1002        False      False      False        False     False         False
# 1003        False      False      False        False     False         False
# 1004        False      False      False        False     False         False
#
# ...

# %%
df.isnull().sum()
# Out:
# OverallQual        0
# GrLivArea          0
# YearBuilt          0
# TotalBsmtSF       15
# FullBath           0
# BedroomAbvGr       0
# GarageCars         0
# GarageArea        15
# LotArea           15
# Neighborhood       0
# HouseStyle         0
# Exterior          15
# GarageType       203
# SaleCondition      0
# SalePrice          0
# dtype: int64

# %%
df.isnull().mean() * 100
# Out:
# OverallQual       0.000000
# GrLivArea         0.000000
# YearBuilt         0.000000
# TotalBsmtSF       1.492537
# FullBath          0.000000
# BedroomAbvGr      0.000000
# GarageCars        0.000000
# GarageArea        1.492537
# LotArea           1.492537
# Neighborhood      0.000000
# HouseStyle        0.000000
# Exterior          1.492537
# GarageType       20.199005
# SaleCondition     0.000000
# SalePrice         0.000000
# dtype: float64

# %%
df.notnull()
# Out:
#       OverallQual  GrLivArea  YearBuilt  TotalBsmtSF  FullBath  BedroomAbvGr  \
# 0            True       True       True         True      True          True
# 1            True       True       True         True      True          True
# 2            True       True       True         True      True          True
# 3            True       True       True         True      True          True
# 4            True       True       True         True      True          True
# ...           ...        ...        ...          ...       ...           ...
# 1000         True       True       True         True      True          True
# 1001         True       True       True         True      True          True
# 1002         True       True       True         True      True          True
# 1003         True       True       True         True      True          True
# 1004         True       True       True         True      True          True
#
# ...

# %%
df.dropna()
# Out:
#       OverallQual  GrLivArea  YearBuilt  TotalBsmtSF  FullBath  BedroomAbvGr  \
# 0               9     1654.0       1971       1592.0         1             4
# 1               6     2344.0       1948        716.0         1             2
# 2               7     1928.0       1978       1138.0         1             1
# 3               9     1240.0       1916       1308.0         1             2
# 4               5     1096.0       1959       1337.0         2             1
# ...           ...        ...        ...          ...       ...           ...
# 998            10     1834.0       1910       1370.0         3             2
# 999             5     1635.0       1976       1013.0         1             1
# 1000            5      729.0       1931       1327.0         3             1
# 1003            5     1066.0       1906       1419.0         3             1
# 1004            9     2233.0       1995       1598.0         1             1
#
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1000     True
# 1001     True
# 1002     True
# 1003     True
# 1004     True
# Length: 1005, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(5)

# %%
df['Neighborhood'].unique()
# Out:
# array(['NridgHt', 'Gilbert', 'Crawfor', 'Edwards', 'Sawyer', 'OldTown',
#        'NAmes', 'BrkSide', 'CollgCr', 'Somerst'], dtype=object)

# %%
df['Neighborhood'].nunique()
# Out:
# 10

# %%
df['Neighborhood'].value_counts().head(5)
# Out:
# Neighborhood
# Somerst    120
# Crawfor    118
# OldTown    108
# Sawyer     107
# NridgHt     98
# Name: count, dtype: int64

# %%
df.groupby("Neighborhood")["SalePrice"].mean()
# Out:
# Neighborhood
# BrkSide    351453.479167
# CollgCr    347445.308642
# Crawfor    348309.805085
# Edwards    368870.597938
# Gilbert    353475.515464
# NAmes      348016.204819
# NridgHt    363892.918367
# OldTown    335293.981481
# Sawyer     351197.261682
# Somerst    348144.558333
# Name: SalePrice, dtype: float64

# %% [markdown]
# Group **By**

# %%
df.groupby("Neighborhood")["SalePrice"].mean()
# Out:
# Neighborhood
# BrkSide    351453.479167
# CollgCr    347445.308642
# Crawfor    348309.805085
# Edwards    368870.597938
# Gilbert    353475.515464
# NAmes      348016.204819
# NridgHt    363892.918367
# OldTown    335293.981481
# Sawyer     351197.261682
# Somerst    348144.558333
# Name: SalePrice, dtype: float64

# %%
df.groupby("HouseStyle")["SalePrice"].mean()
# Out:
# HouseStyle
# 1.5Fin    343740.943878
# 1Story    355197.666667
# 2Story    354012.900498
# SFoyer    358224.990868
# SLvl      345256.695000
# Name: SalePrice, dtype: float64

# %%
df.groupby("Neighborhood").agg({
    "SalePrice": "mean",
    "GrLivArea": "mean"
})
# Out:
#                   SalePrice    GrLivArea
# Neighborhood
# BrkSide       351453.479167  1476.166667
# CollgCr       347445.308642  1505.370370
# Crawfor       348309.805085  1581.398305
# Edwards       368870.597938  1506.494845
# Gilbert       353475.515464  1551.649485
# NAmes         348016.204819  1514.265060
# NridgHt       363892.918367  1552.193878
# OldTown       335293.981481  1522.305556
# Sawyer        351197.261682  1484.168224
# Somerst       348144.558333  1521.383333

# %%
df["SalePrice"].mean()
# Out:
# np.float64(351407.7502487562)

# %%
df.rename(
    columns={"SalePrice": "Sale_Price"},
    inplace=True
)

# %%
df["Neighborhood"].str.upper()
# Out:
# 0       NRIDGHT
# 1       GILBERT
# 2       CRAWFOR
# 3       EDWARDS
# 4       GILBERT
#          ...
# 1000    OLDTOWN
# 1001    NRIDGHT
# 1002    CRAWFOR
# 1003    OLDTOWN
# 1004    BRKSIDE
# Name: Neighborhood, Length: 1005, dtype: object

# %% [markdown]
# Data Cleaning

# %%
import numpy as np

# %%
clean_df = df.copy()

# %%
clean_df.isnull().sum()
# Out:
# OverallQual        0
# GrLivArea          0
# YearBuilt          0
# TotalBsmtSF       15
# FullBath           0
# BedroomAbvGr       0
# GarageCars         0
# GarageArea        15
# LotArea           15
# Neighborhood       0
# HouseStyle         0
# Exterior          15
# GarageType       203
# SaleCondition      0
# Sale_Price         0
# dtype: int64

# %%
missing = clean_df.isnull().sum()

missing[missing > 0]
# Out:
# TotalBsmtSF     15
# GarageArea      15
# LotArea         15
# Exterior        15
# GarageType     203
# dtype: int64

# %%
missing_percent = (clean_df.isnull().sum() / len(clean_df)) * 100

missing_percent[missing_percent > 0]
# Out:
# TotalBsmtSF     1.492537
# GarageArea      1.492537
# LotArea         1.492537
# Exterior        1.492537
# GarageType     20.199005
# dtype: float64

# %%
missing_percent=(clean_df.isnull().sum()/len(clean_df))*100
missing_percent[missing_percent>0]
# Out:
# TotalBsmtSF     1.492537
# GarageArea      1.492537
# LotArea         1.492537
# Exterior        1.492537
# GarageType     20.199005
# dtype: float64

# %%
mean_price = df["Sale_Price"].mean()

print("Average House Price:", mean_price)
# Out:
# Average House Price: 351407.7502487562

# %%
variance = df["Sale_Price"].var()

print("Variance:", variance)
# Out:
# Variance: 6939504272.1935425

# %%
q1 = df["Sale_Price"].quantile(0.25)
q2 = df["Sale_Price"].quantile(0.50)
q3 = df["Sale_Price"].quantile(0.75)

print("Q1:", q1)
print("Median:", q2)
print("Q3:", q3)
# Out:
# Q1: 295832.0
# Median: 352767.0
# Q3: 403595.0

# %%
df.columns
# Out:
# Index(['OverallQual', 'GrLivArea', 'YearBuilt', 'TotalBsmtSF', 'FullBath',
#        'BedroomAbvGr', 'GarageCars', 'GarageArea', 'LotArea', 'Neighborhood',
#        'HouseStyle', 'Exterior', 'GarageType', 'SaleCondition', 'Sale_Price'],
#       dtype='object')

# %%
mean_price = df["Sale_Price"].mean()

print("Average House Price:", mean_price)
# Out:
# Average House Price: 351407.7502487562

# %%
df["Sale_Price"].describe()
# Out:
# count    1.005000e+03
# mean     3.514078e+05
# std      8.330369e+04
# min      1.312610e+05
# 25%      2.958320e+05
# 50%      3.527670e+05
# 75%      4.035950e+05
# max      1.500000e+06
# Name: Sale_Price, dtype: float64

# %% [markdown]
# # **Numpy**

# %%
prices = df["Sale_Price"].to_numpy()

print(prices)
# Out:
# [514675 378454 384495 ... 384972 272664 456241]

# %%
prices = df["Sale_Price"].to_numpy()

average_price = np.mean(prices)

print("Average Price:", average_price)
# Out:
# Average Price: 351407.7502487562

# %%
std_price = np.std(prices)

print("Standard Deviation:", std_price)
# Out:
# Standard Deviation: 83262.23209125624

# %%
min_price = np.min(prices)
max_price = np.max(prices)

print("Minimum Price:", min_price)
print("Maximum Price:", max_price)
# Out:
# Minimum Price: 131261
# Maximum Price: 1500000

# %%
df["PriceCategory"] = np.where(
    df["Sale_Price"] > 300000,
    "High",
    "Low"
)

# %%
df[["Sale_Price", "PriceCategory"]].head(10)
# Out:
#    Sale_Price PriceCategory
# 0      514675          High
# 1      378454          High
# 2      384495          High
# 3      377558          High
# 4      300358          High
# 5      377030          High
# 6      351767          High
# 7      473971          High
# 8      420777          High
# 9      296740           Low

# %% [markdown]
# # **OUTLIERS**

# %%
import matplotlib.pyplot as plt

plt.boxplot(df["Sale_Price"])
plt.title("Sale Price - Outlier Detection")
plt.ylabel("Sale Price")
plt.show()

# %%
Q1=df['Sale_Price'].quantile(0.25)
Q3=df['Sale_Price'].quantile(0.75)
IQR = Q3 - Q1

print("Q1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)
# Out:
# Q1: 295832.0
# Q3: 403595.0
# IQR: 107763.0

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)
# Out:
# Lower Bound: 134187.5
# Upper Bound: 565239.5

# %% [markdown]
# # MATPLOTLIB

# %%
plt.hist(df["Sale_Price"], bins=30)

plt.title("Distribution of House Prices")
plt.xlabel("Sale Price")
plt.ylabel("Number of Houses")

plt.show()

# %%
plt.boxplot(df["Sale_Price"])

plt.title("Sale Price Boxplot")
plt.ylabel("Sale Price")

plt.show()

# %%
plt.scatter(df["GrLivArea"], df["Sale_Price"])

plt.title("Living Area vs Sale Price")
plt.xlabel("Living Area (sq ft)")
plt.ylabel("Sale Price")

plt.show()

# %%
avg_price.plot(kind="bar", figsize=(10,5))

plt.title("Average House Price by Neighborhood")
plt.xlabel("Neighborhood")
plt.ylabel("Average Sale Price")

plt.show()

# %%
import seaborn as sns

corr = df.select_dtypes(include="number").corr()

plt.figure(figsize=(12,8))

sns.heatmap(corr, annot=True)

plt.title("Feature Correlation Heatmap")

plt.show()
